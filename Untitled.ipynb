# %%
import xarray as xr


import pandas as pd

# %%
ddir = '/g/data/ub4/era5/netcdf/pressure/v/'

# %%
data = xr.open_mfdataset(ddir + '1979/*.nc', combine = 'nested', concat_dim = 'time').sel(level = 850).drop('level')

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 309, longitude: 569, time: 8760)
# Coordinates:
#   * latitude   (latitude) float32 20.0 19.75 19.5 19.25 ... -56.5 -56.75 -57.0
#   * longitude  (longitude) float32 78.0 78.25 78.5 78.75 ... 219.5 219.75 220.0
#   * time       (time) datetime64[ns] 1979-01-01 ... 1979-12-31T23:00:00
# Data variables:
#     v          (time, latitude, longitude) float32 dask.array<chunksize=(744, 309, 569), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2019-03-29 05:20:23 GMT by grib_to_netcdf-2.10.0: /opt/ecmw...
