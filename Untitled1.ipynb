# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
directory  = '/g/data/w40/ab2313/'
path = directory + 'precip_calib_0.25_1911_2017_land.nc'
awap = xr.open_dataset(path)

# %%
awap
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 139, lon: 178, time: 39082)
# Coordinates:
#   * lon      (lon) float64 112.0 112.2 112.5 112.8 ... 155.5 155.8 156.0 156.2
#   * lat      (lat) float64 -44.5 -44.25 -44.0 -43.75 ... -10.5 -10.25 -10.0
#   * time     (time) datetime64[ns] 1911-01-01T09:00:00 ... 2017-12-31T09:00:00
# Data variables:
#     precip   (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.6.2 (http://code.zmaw.de/p...
#     Conventions:  CF-1.4
#     history:      Fri Dec 07 18:54:17 2018: cdo ifthen grid_0.25.nc precip_ca...
#     CDO:          Climate Data Operators version 1.6.2 (http://code.zmaw.de/p...

# %%
nino34 = xr.open_dataset('extreme_calc/nino34_daily_filled_month_average(00:00).nc')
nino34
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 16102)
# Coordinates:
#   * time     (time) datetime64[ns] 1974-10-01 1974-10-02 ... 2018-10-31
# Data variables:
#     nino34   (time) float64 ...
# Attributes:
#     Source:   BOM
#     Extra:    This is a monthly average that has been made every day into tha...

# %%
import sys
sys.path.append('')
import alex as al

# %%
from importlib import reload

# %%
al = reload(al)
al.add(3,2)
# Out:
# 7

# %%
al = reload(al)
resample_data = al.awap_func(awap)

# %%
n2 = nino34.expand_dims(lat = awap.lat.values, lon = awap.lon.values)

# %%
n2

# %%
n2.isel(time = 10).nino34.plot()

# %%
x = awap - awap.mean(dim = 'time')
y = n2 - n2.mean(dim = 'time')

# %%
import sys

sys.path.append('')

import functions as func

from importlib import reload

func = reload(func)
func._func(1,2)
# Out:
# 5

# %%
func = reload(func)
func._func(1,2)
# Out:
# 5

# %%
import datetime as dt

# %%
awap
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 139, lon: 178, time: 39082)
# Coordinates:
#   * lon      (lon) float64 112.0 112.2 112.5 112.8 ... 155.5 155.8 156.0 156.2
#   * lat      (lat) float64 -44.5 -44.25 -44.0 -43.75 ... -10.5 -10.25 -10.0
#   * time     (time) datetime64[ns] 1911-01-01T09:00:00 ... 2017-12-31T09:00:00
# Data variables:
#     precip   (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.6.2 (http://code.zmaw.de/p...
#     Conventions:  CF-1.4
#     history:      Fri Dec 07 18:54:17 2018: cdo ifthen grid_0.25.nc precip_ca...
#     CDO:          Climate Data Operators version 1.6.2 (http://code.zmaw.de/p...

# %%
time = awap.time.values
time
# Out:
# array(['1911-01-01T09:00:00.000000000', '1911-01-02T09:00:00.000000000',
#        '1911-01-03T09:00:00.000000000', ...,
#        '2017-12-29T09:00:00.000000000', '2017-12-30T09:00:00.000000000',
#        '2017-12-31T09:00:00.000000000'], dtype='datetime64[ns]')

# %%
awap.time.dt.month.values
# Out:
# array([ 1,  1,  1, ..., 12, 12, 12])

# %%
awap.where(awap.time.dt.month == 1, drop = True)
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 139, lon: 178, time: 3317)
# Coordinates:
#   * lon      (lon) float64 112.0 112.2 112.5 112.8 ... 155.5 155.8 156.0 156.2
#   * lat      (lat) float64 -44.5 -44.25 -44.0 -43.75 ... -10.5 -10.25 -10.0
#   * time     (time) datetime64[ns] 1911-01-01T09:00:00 ... 2017-01-31T09:00:00
# Data variables:
#     precip   (time, lat, lon) float32 nan nan nan nan nan ... nan nan nan nan
# Attributes:
#     CDI:          Climate Data Interface version 1.6.2 (http://code.zmaw.de/p...
#     Conventions:  CF-1.4
#     history:      Fri Dec 07 18:54:17 2018: cdo ifthen grid_0.25.nc precip_ca...
#     CDO:          Climate Data Operators version 1.6.2 (http://code.zmaw.de/p...

# %%
awap.where(awap.precip < 1)
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 139, lon: 178, time: 39082)
# Coordinates:
#   * lon      (lon) float64 112.0 112.2 112.5 112.8 ... 155.5 155.8 156.0 156.2
#   * lat      (lat) float64 -44.5 -44.25 -44.0 -43.75 ... -10.5 -10.25 -10.0
#   * time     (time) datetime64[ns] 1911-01-01T09:00:00 ... 2017-12-31T09:00:00
# Data variables:
#     precip   (time, lat, lon) float32 nan nan nan nan nan ... nan nan nan nan
# Attributes:
#     CDI:          Climate Data Interface version 1.6.2 (http://code.zmaw.de/p...
#     Conventions:  CF-1.4
#     history:      Fri Dec 07 18:54:17 2018: cdo ifthen grid_0.25.nc precip_ca...
#     CDO:          Climate Data Operators version 1.6.2 (http://code.zmaw.de/p...

# %%
awap
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 139, lon: 178, time: 39082)
# Coordinates:
#   * lon      (lon) float64 112.0 112.2 112.5 112.8 ... 155.5 155.8 156.0 156.2
#   * lat      (lat) float64 -44.5 -44.25 -44.0 -43.75 ... -10.5 -10.25 -10.0
#   * time     (time) datetime64[ns] 1911-01-01T09:00:00 ... 2017-12-31T09:00:00
# Data variables:
#     precip   (time, lat, lon) float32 nan nan nan nan nan ... nan nan nan nan
# Attributes:
#     CDI:          Climate Data Interface version 1.6.2 (http://code.zmaw.de/p...
#     Conventions:  CF-1.4
#     history:      Fri Dec 07 18:54:17 2018: cdo ifthen grid_0.25.nc precip_ca...
#     CDO:          Climate Data Operators version 1.6.2 (http://code.zmaw.de/p...

# %%
a2 = awap.isel(time = slice(38000,39082))

# %%
a2
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 139, lon: 178, time: 1082)
# Coordinates:
#   * lon      (lon) float64 112.0 112.2 112.5 112.8 ... 155.5 155.8 156.0 156.2
#   * lat      (lat) float64 -44.5 -44.25 -44.0 -43.75 ... -10.5 -10.25 -10.0
#   * time     (time) datetime64[ns] 2015-01-15T09:00:00 ... 2017-12-31T09:00:00
# Data variables:
#     precip   (time, lat, lon) float32 nan nan nan nan nan ... nan nan nan nan
# Attributes:
#     CDI:          Climate Data Interface version 1.6.2 (http://code.zmaw.de/p...
#     Conventions:  CF-1.4
#     history:      Fri Dec 07 18:54:17 2018: cdo ifthen grid_0.25.nc precip_ca...
#     CDO:          Climate Data Operators version 1.6.2 (http://code.zmaw.de/p...

# %%
nino34
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 16102)
# Coordinates:
#   * time     (time) datetime64[ns] 1974-10-01 1974-10-02 ... 2018-10-31
# Data variables:
#     nino34   (time) float64 -0.75 -0.75 -0.75 -0.75 ... 0.84 0.84 0.84 0.84
# Attributes:
#     Source:   BOM
#     Extra:    This is a monthly average that has been made every day into tha...

# %%
elnino = nino34.where(nino34 > 1, drop = True)

# %%
elnino
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1917)
# Coordinates:
#   * time     (time) datetime64[ns] 1977-11-01 1977-11-02 ... 2016-04-30
# Data variables:
#     nino34   (time) float64 1.03 1.03 1.03 1.03 1.03 ... 1.05 1.05 1.05 1.05
# Attributes:
#     Source:   BOM
#     Extra:    This is a monthly average that has been made every day into tha...

# %%
nino34
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 16102)
# Coordinates:
#   * time     (time) datetime64[ns] 1974-10-01 1974-10-02 ... 2018-10-31
# Data variables:
#     nino34   (time) float64 -0.75 -0.75 -0.75 -0.75 ... 0.84 0.84 0.84 0.84
# Attributes:
#     Source:   BOM
#     Extra:    This is a monthly average that has been made every day into tha...

# %%
import pandas as pd

# %%
a2['time'] = a2.time.values - pd.to_timedelta('9h')

# %%
a2
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 139, lon: 178, time: 1082)
# Coordinates:
#   * lon      (lon) float64 112.0 112.2 112.5 112.8 ... 155.5 155.8 156.0 156.2
#   * lat      (lat) float64 -44.5 -44.25 -44.0 -43.75 ... -10.5 -10.25 -10.0
#   * time     (time) datetime64[ns] 2015-01-15 2015-01-16 ... 2017-12-31
# Data variables:
#     precip   (time, lat, lon) float32 nan nan nan nan nan ... nan nan nan nan
# Attributes:
#     CDI:          Climate Data Interface version 1.6.2 (http://code.zmaw.de/p...
#     Conventions:  CF-1.4
#     history:      Fri Dec 07 18:54:17 2018: cdo ifthen grid_0.25.nc precip_ca...
#     CDO:          Climate Data Operators version 1.6.2 (http://code.zmaw.de/p...

# %%
a2.where(a2.time.isin(elnino.time.values), drop = True)
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 139, lon: 178, time: 366)
# Coordinates:
#   * lon      (lon) float64 112.0 112.2 112.5 112.8 ... 155.5 155.8 156.0 156.2
#   * lat      (lat) float64 -44.5 -44.25 -44.0 -43.75 ... -10.5 -10.25 -10.0
#   * time     (time) datetime64[ns] 2015-05-01 2015-05-02 ... 2016-04-30
# Data variables:
#     precip   (time, lat, lon) float32 nan nan nan nan nan ... nan nan nan nan
# Attributes:
#     CDI:          Climate Data Interface version 1.6.2 (http://code.zmaw.de/p...
#     Conventions:  CF-1.4
#     history:      Fri Dec 07 18:54:17 2018: cdo ifthen grid_0.25.nc precip_ca...
#     CDO:          Climate Data Operators version 1.6.2 (http://code.zmaw.de/p...
